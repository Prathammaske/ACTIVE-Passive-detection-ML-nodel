# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('AV_and_PV.csv')

# %%
df
# Out:
#     Unnamed: 0 helping_verbs verb_form extraa    voice
# 0            0           NaN       VBP    NaN   active
# 1            1           NaN       VBP    NaN   active
# 2            2           NaN       VBP    NaN   active
# 3            3           NaN       VBZ    NaN   active
# 4            4           NaN       VBZ    NaN   active
# 5            5           NaN       VBZ    NaN   active
# 6            6            am       VBN     by  passive
# 7            7            is       VBN     by  passive
# 8            8           are       VBN     by  passive
# 9            9            am       VBN    NaN  passive
# 10          10            is       VBN    NaN  passive
# 11          11           are       VBN    NaN  passive
# 12          12            am       VBG    NaN   active
# 13          13            is       VBG    NaN   active
# 14          14           are       VBG    NaN   active
# 15          15            am       VBN    NaN  passive
# ...

# %%
df.shape
# Out:
# (56, 5)

# %%
df.describe()
# Out:
#        Unnamed: 0
# count   56.000000
# mean    27.500000
# std     16.309506
# min      0.000000
# 25%     13.750000
# 50%     27.500000
# 75%     41.250000
# max     55.000000

# %%
df['verb_form'].value_counts()
# Out:
# verb_form
# VBN    39
# VBG     8
# VBP     3
# VBZ     3
# VBD     2
# VB      1
# Name: count, dtype: int64

# %%
df['helping_verbs'].value_counts()
# Out:
# helping_verbs
# will    14
# am       5
# is       5
# are      5
# was      5
# were     5
# have     3
# has      3
# had      3
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Unnamed: 0        0
# helping_verbs     8
# verb_form         0
# extraa           30
# voice             0
# dtype: int64

# %%
#df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0        0
# helping_verbs     8
# verb_form         0
# extraa           30
# voice             0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()
df['voice']= lb.fit_transform(df['voice'])

# %%
df
# Out:
#     Unnamed: 0 helping_verbs verb_form extraa  voice
# 0            0           NaN       VBP    NaN      0
# 1            1           NaN       VBP    NaN      0
# 2            2           NaN       VBP    NaN      0
# 3            3           NaN       VBZ    NaN      0
# 4            4           NaN       VBZ    NaN      0
# 5            5           NaN       VBZ    NaN      0
# 6            6            am       VBN     by      1
# 7            7            is       VBN     by      1
# 8            8           are       VBN     by      1
# 9            9            am       VBN    NaN      1
# 10          10            is       VBN    NaN      1
# 11          11           are       VBN    NaN      1
# 12          12            am       VBG    NaN      0
# 13          13            is       VBG    NaN      0
# 14          14           are       VBG    NaN      0
# 15          15            am       VBN    NaN      1
# 16          16            is       VBN    NaN      1
# ...

# %%
helping_verbs = {
'will'  :  8,
'am'    :   7,
'is'    :   6,
'are'   :  5,
'have'  :   4,
'has'   :   3,
'was'   :   2,
'were'  :   1,
'had'   :   0,

    
}

# %%
df['helping_verbs']=df['helping_verbs'].map(helping_verbs)

# %%
df
# Out:
#     Unnamed: 0  helping_verbs verb_form extraa  voice
# 0            0            NaN       VBP    NaN      0
# 1            1            NaN       VBP    NaN      0
# 2            2            NaN       VBP    NaN      0
# 3            3            NaN       VBZ    NaN      0
# 4            4            NaN       VBZ    NaN      0
# 5            5            NaN       VBZ    NaN      0
# 6            6            7.0       VBN     by      1
# 7            7            6.0       VBN     by      1
# 8            8            5.0       VBN     by      1
# 9            9            7.0       VBN    NaN      1
# 10          10            6.0       VBN    NaN      1
# 11          11            5.0       VBN    NaN      1
# 12          12            7.0       VBG    NaN      0
# 13          13            6.0       VBG    NaN      0
# 14          14            5.0       VBG    NaN      0
# 15          15            7.0       VBN    NaN      1
# ...

# %%
df.shape
# Out:
# (56, 5)

# %%
df['extraa'].value_counts()
# Out:
# extraa
# being    10
# by        6
# been      6
# be        4
# Name: count, dtype: int64

# %%
extraa = {
'being'   : 3,
'by'      :  2,
'been'    :  1,
'be'      :  0,
    
}

# %%
df['extraa']=df['extraa'].map(extraa)

# %%
df
# Out:
#     Unnamed: 0  helping_verbs verb_form  extraa  voice
# 0            0            NaN       VBP     NaN      0
# 1            1            NaN       VBP     NaN      0
# 2            2            NaN       VBP     NaN      0
# 3            3            NaN       VBZ     NaN      0
# 4            4            NaN       VBZ     NaN      0
# 5            5            NaN       VBZ     NaN      0
# 6            6            7.0       VBN     2.0      1
# 7            7            6.0       VBN     2.0      1
# 8            8            5.0       VBN     2.0      1
# 9            9            7.0       VBN     NaN      1
# 10          10            6.0       VBN     NaN      1
# 11          11            5.0       VBN     NaN      1
# 12          12            7.0       VBG     NaN      0
# 13          13            6.0       VBG     NaN      0
# 14          14            5.0       VBG     NaN      0
# 15          15            7.0       VBN     NaN      1
# ...

# %%
verb_form = {
'VBN' :   5,
'VBG' :    4,
'VBP' :    3,
'VBZ' :  2,
'VBD' :   1,
'VB'  :    0,
}

# %%
df['verb_form']=df['verb_form'].map(verb_form)

# %%
df
# Out:
#     Unnamed: 0  helping_verbs  verb_form  extraa  voice
# 0            0            NaN          3     NaN      0
# 1            1            NaN          3     NaN      0
# 2            2            NaN          3     NaN      0
# 3            3            NaN          2     NaN      0
# 4            4            NaN          2     NaN      0
# 5            5            NaN          2     NaN      0
# 6            6            7.0          5     2.0      1
# 7            7            6.0          5     2.0      1
# 8            8            5.0          5     2.0      1
# 9            9            7.0          5     NaN      1
# 10          10            6.0          5     NaN      1
# 11          11            5.0          5     NaN      1
# 12          12            7.0          4     NaN      0
# 13          13            6.0          4     NaN      0
# 14          14            5.0          4     NaN      0
# 15          15            7.0          5     NaN      1
# ...

# %%
df.corr()
# Out:
#                Unnamed: 0  helping_verbs  verb_form    extraa     voice
# Unnamed: 0       1.000000       0.180062   0.203194 -0.367103  0.081968
# helping_verbs    0.180062       1.000000  -0.197782 -0.322274 -0.156685
# verb_form        0.203194      -0.197782   1.000000  0.606866  0.640829
# extraa          -0.367103      -0.322274   0.606866  1.000000  0.606866
# voice            0.081968      -0.156685   0.640829  0.606866  1.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['extraa'].value_counts()
# Out:
# extraa
# 3.0    10
# 2.0     6
# 1.0     6
# 0.0     4
# Name: count, dtype: int64

# %%
mean_value = df['extraa'].mean()

# Fill NaN values in the 'extraa' column with the mean value
df['extraa'] = df['extraa'].fillna(mean_value)

# %%
mean_value = df['helping_verbs'].mean()

# Fill NaN values in the 'extraa' column with the mean value
df['helping_verbs'] = df['helping_verbs'].fillna(mean_value)

# %%
df
# Out:
#     Unnamed: 0  helping_verbs  verb_form    extraa  voice
# 0            0       4.958333          3  1.846154      0
# 1            1       4.958333          3  1.846154      0
# 2            2       4.958333          3  1.846154      0
# 3            3       4.958333          2  1.846154      0
# 4            4       4.958333          2  1.846154      0
# 5            5       4.958333          2  1.846154      0
# 6            6       7.000000          5  2.000000      1
# 7            7       6.000000          5  2.000000      1
# 8            8       5.000000          5  2.000000      1
# 9            9       7.000000          5  1.846154      1
# 10          10       6.000000          5  1.846154      1
# 11          11       5.000000          5  1.846154      1
# 12          12       7.000000          4  1.846154      0
# 13          13       6.000000          4  1.846154      0
# 14          14       5.000000          4  1.846154      0
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0       0
# helping_verbs    0
# verb_form        0
# extraa           0
# voice            0
# dtype: int64

# %%
df.corr()
# Out:
#                Unnamed: 0  helping_verbs  verb_form    extraa     voice
# Unnamed: 0       1.000000       0.151523   0.203194 -0.227610  0.081968
# helping_verbs    0.151523       1.000000  -0.119422 -0.243336 -0.136673
# verb_form        0.203194      -0.119422   1.000000  0.109944  0.640829
# extraa          -0.227610      -0.243336   0.109944  1.000000  0.268537
# voice            0.081968      -0.136673   0.640829  0.268537  1.000000

# %%
sns.pairplot(df,hue='voice')

# %%
X=df.drop(columns=['voice'])

# %%
y=df['voice']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB

# %%
mod = LogisticRegression()
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB()

# %%
mod.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
mnb.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
bnb.fit(x_train,y_train)
# Out:
# BernoulliNB()

# %%
from sklearn.metrics import accuracy_score as acc_score, precision_score as prec_score

# %%
y_pred=mod.predict(x_test)
print(acc_score(y_test,y_pred))
print(prec_score(y_test,y_pred))
# Out:
# 0.9285714285714286
# 0.9

# %%
y_pred=bnb.predict(testx)
print(acc_score(y_test,y_pred))
print(prec_score(y_test,y_pred))
# Out:
# 0.5
# 0.5833333333333334

# %%
y_pred=gnb.predict(testx)
print(acc_score(y_test,y_pred))
print(prec_score(y_test,y_pred))
# Out:
# 0.42857142857142855
# 0.5555555555555556

# %%
y_pred=mnb.predict(testx)
print(acc_score(y_test,y_pred))
print(prec_score(y_test,y_pred))
# Out:
# 0.42857142857142855
# 0.5454545454545454

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, BaggingClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
svc= SVC(kernel='sigmoid', gamma=1.0)
knc=KNeighborsClassifier()
mnb=MultinomialNB()
dtc= DecisionTreeClassifier(max_depth=5)
lrc= LogisticRegression(solver='liblinear', penalty='l1')
rfc= RandomForestClassifier(n_estimators=50, random_state=2)
abc =AdaBoostClassifier(n_estimators=50, random_state=2)
bc =BaggingClassifier(n_estimators=50, random_state=2)
etc =ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt =GradientBoostingClassifier(n_estimators=50, random_state=2)
xgb =XGBClassifier(n_estimators=50, random_state=2)

# %%
clfs={
    'SVC':svc,
    'KN':knc,
    'NB':mnb,
    'DT':dtc,
    'LR':lrc,
    'RF':rfc,
    'AdaBoost':abc,
    'BgC':bc,
    'ETC':etc,
    'GBDT':gbdt,
    'xgb':xgb
}

# %%
def train_classifier(clf, x_train, y_train, x_test, y_test):
    clf.fit(x_train, y_train)
    y_pred = clf.predict(x_test)
    accuracy = acc_score(y_test, y_pred)
    precision = prec_score(y_test, y_pred)
    return accuracy, precision

# %%
accuracy_score=[]
precision_score=[]
for name,clf in clfs.items():
    currentacc,currentpreci=train_classifier(clf,x_train,y_train,x_test,y_test)
    print('For',name)
    print('acuuracy',currentacc)
    print('precision',currentpreci)
    accuracy_score.append(currentacc)
    precision_score.append(currentpreci)
# Out:
# For SVC
# acuuracy 0.6428571428571429
# precision 0.6428571428571429
# For KN
# acuuracy 0.5
# precision 0.6666666666666666
# For NB
# acuuracy 0.7142857142857143
# precision 0.7777777777777778
# For DT
# acuuracy 0.9285714285714286
# precision 0.9
# For LR
# acuuracy 0.7857142857142857
# precision 0.875
# For RF
# acuuracy 0.9285714285714286
# precision 0.9
# C:\Users\prath\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# For AdaBoost
# acuuracy 0.9285714285714286
# precision 0.9
# For BgC
# acuuracy 0.9285714285714286
# precision 0.9
# For ETC
# acuuracy 0.9285714285714286
# precision 0.9
# For GBDT
# acuuracy 0.9285714285714286
# precision 0.9
# For xgb
# acuuracy 0.7857142857142857
# precision 0.875

# %%
performance_df=pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_score,'Precision':precision_score})

# %%
performance_df
# Out:
#    Algorithm  Accuracy  Precision
# 0        SVC  0.642857   0.642857
# 1         KN  0.500000   0.666667
# 2         NB  0.714286   0.777778
# 3         DT  0.928571   0.900000
# 4         LR  0.785714   0.875000
# 5         RF  0.928571   0.900000
# 6   AdaBoost  0.928571   0.900000
# 7        BgC  0.928571   0.900000
# 8        ETC  0.928571   0.900000
# 9       GBDT  0.928571   0.900000
# 10       xgb  0.785714   0.875000

# %%
#MODELIMPROVEMENT

# %%
estimators=[('mod',svc),('GBDT',mnb),('ETC',etc)]
final_estimator=RandomForestClassifier()

# %%
from sklearn.ensemble import StackingClassifier

# %%
clf=StackingClassifier(estimators=estimators,final_estimator=final_estimator)

# %%
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)

# %%
accuracy = acc_score(y_test, y_pred)
precision = prec_score(y_test, y_pred, average='macro')  # Adjust 'average' if needed

print('accuracy is', accuracy)
print('precision is', precision)
# Out:
# accuracy is 0.9285714285714286
# precision is 0.95
